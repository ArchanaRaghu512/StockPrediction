# %%
import pandas as pd
xl = pd.ExcelFile('2005.xlsx', low_memory=False)
print(xl.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df1 = xl.parse(xl.sheet_names[0])
df2 = xl.parse(xl.sheet_names[1])

df1.head()
# Out:
#                         Date Name price_date                   company Ticker  \
# 0      38383 1-800 CONTACTS, INC. 2005-01-31      1-800 CONTACTS, INC.   CTAC
# 1      38349 1-800-ATTORNEY, Inc. 2004-12-28      1-800-ATTORNEY, Inc.   ATTY
# 2         38383 1-800-FLOWERS.COM 2005-01-31         1-800-FLOWERS.COM   FLWS
# 3    38365 1st Centennial Bancorp 2005-01-13    1st Centennial Bancorp   FCEN
# 4  38383 1st Constitution Bancorp 2005-01-31  1st Constitution Bancorp   FCCY
#
#   Standard and Poor stock          Sector SIC primary code  \
# 0                    None   09 - Services             5961
# 1                    None   09 - Services             2741
# 2                    None   09 - Services             5992
# 3                    None  07 - Financial             6712
# 4                    None  07 - Financial             6712
#
#                                 Industry EPS Est Q0  \
# 0   0948 - Retail (Catalog & Mail Order)       0.13
# ...

# %%
df2.head()
# Out:
#                                  price_date                     company  \
# 38355 Avesis Incorporated        2005-01-03         Avesis Incorporated
# 38355 Chinawe.com Inc.           2005-01-03            Chinawe.com Inc.
# 38355 CreditRiskMonitor.com, Inc 2005-01-03  CreditRiskMonitor.com, Inc
# 38355 English Language Learning  2005-01-03   English Language Learning
# 38355 Indian Village Bancorp     2005-01-03      Indian Village Bancorp
#
#                                  ticker  price split_date  split_fact  \
# 38355 Avesis Incorporated          AVSS   0.31        NaT         0.0
# 38355 Chinawe.com Inc.             CHWE   0.09        NaT         0.0
# 38355 CreditRiskMonitor.com, Inc   CRMZ   0.40        NaT         0.0
# 38355 English Language Learning    ELLG   0.12        NaT         0.0
# 38355 Indian Village Bancorp       IDVB  16.75 2004-12-16         1.1
#
#                                   Split Adjusted Price    P+1    P+2    P+3  \
# ...

# %%
for i in df1.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
for i in df2.columns:
    print(i)
# Out:
# price_date
# company
# ticker
# price
# split_date
# split_fact
# Split Adjusted Price
# P+1
# P+2
# P+3
# P+4
# P+5
# P+6
# P+7
# P+8
# P+9
# P+10
# P+11
# P+12
# R+1
# R+2
# R+3
# R+4
# R+5
# R+6
# R+7
# R+8
# R+9
# R+10
# R+11
# R+12

# %%
xl06 = pd.ExcelFile('2006.xlsx', low_memory=False)
print(xl06.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df106 = xl06.parse(xl06.sheet_names[0])
df206 = xl06.parse(xl06.sheet_names[1])

# %%
df106.head()
# Out:
#                         Date Name price_date                   company Ticker  \
# 0      38748 1-800 CONTACTS, INC. 2006-01-31      1-800 CONTACTS, INC.   CTAC
# 1      38743 1-800-ATTORNEY, Inc. 2006-01-26      1-800-ATTORNEY, Inc.   ATTY
# 2         38748 1-800-FLOWERS.COM 2006-01-31         1-800-FLOWERS.COM   FLWS
# 3    38748 1st Centennial Bancorp 2006-01-31    1st Centennial Bancorp   FCEN
# 4  38748 1st Constitution Bancorp 2006-01-31  1st Constitution Bancorp   FCCY
#
#   Standard and Poor stock          Sector SIC primary code  \
# 0                    None   09 - Services             5961
# 1                    None   09 - Services             2741
# 2                    None   09 - Services             5992
# 3                    None  07 - Financial             6712
# 4                    None  07 - Financial             6712
#
#                                 Industry EPS Est Q0  \
# 0   0948 - Retail (Catalog & Mail Order)          0
# ...

# %%
df206.head()
# Out:
#                                     price_date                        company  \
# 38720 Berliner Communications, Inc. 2006-01-03  Berliner Communications, Inc.
# 38720 Complete Wellness Centers     2006-01-03      Complete Wellness Centers
# 38720 Complete Wellness Centers     2006-01-03      Complete Wellness Centers
# 38720 Helionetics, Inc.             2006-01-03              Helionetics, Inc.
# 38720 Helionetics, Inc.             2006-01-03              Helionetics, Inc.
#
#                                     ticker  price split_date  split_fact  \
# 38720 Berliner Communications, Inc.   BERL    0.4 2005-09-19         0.0
# 38720 Complete Wellness Centers      CMWLQ    0.0        NaT         0.0
# 38720 Complete Wellness Centers      CMWLQ    0.0        NaT         0.0
# 38720 Helionetics, Inc.               HLXC    0.0 1996-04-11         0.1
# 38720 Helionetics, Inc.               HLXC    0.0 1996-04-11         0.1
#
# ...

# %%
for i in df106.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
xl07 = pd.ExcelFile('2007.xlsx', low_memory=False)
print(xl07.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df107 = xl07.parse(xl07.sheet_names[0])
df207 = xl07.parse(xl07.sheet_names[1])

# %%
df107.head()
# Out:
#                         Date Name price_date                   company Ticker  \
# 0      39113 1-800 CONTACTS, INC. 2007-01-31      1-800 CONTACTS, INC.   CTAC
# 1      39107 1-800-ATTORNEY, Inc. 2007-01-25      1-800-ATTORNEY, Inc.   ATTY
# 2   39113 1-800-FLOWERS.COM, Inc. 2007-01-31   1-800-FLOWERS.COM, Inc.   FLWS
# 3    39113 1st Centennial Bancorp 2007-01-31    1st Centennial Bancorp   FCEN
# 4  39112 1st Constitution Bancorp 2007-01-30  1st Constitution Bancorp   FCCY
#
#   Standard and Poor stock          Sector SIC primary code  \
# 0                    None   09 - Services             5961
# 1                    None   09 - Services             2741
# 2                    None   09 - Services             5992
# 3                    None  07 - Financial             6712
# 4                    None  07 - Financial             6712
#
#                                 Industry EPS Est Q0  \
# 0   0948 - Retail (Catalog & Mail Order)      -0.19
# ...

# %%
df207.head()
# Out:
#                                     price_date                        company  \
# 39085 Allegro Group Inc.            2007-01-03             Allegro Group Inc.
# 39085 Beres Industries Inc.         2007-01-03          Beres Industries Inc.
# 39085 Boston Restaurant Associates, 2007-01-03  Boston Restaurant Associates,
# 39085 Boston Restaurant Associates, 2007-01-03  Boston Restaurant Associates,
# 39085 Boston Restaurant Associates, 2007-01-03  Boston Restaurant Associates,
#
#                                     ticker  price split_date  split_fact  \
# 39085 Allegro Group Inc.              ALLG   0.15 2006-05-22        0.01
# 39085 Beres Industries Inc.           BERS   0.00        NaT        0.00
# 39085 Boston Restaurant Associates,   BRAI   0.96        NaT        0.00
# 39085 Boston Restaurant Associates,   BRAI   0.96        NaT        0.00
# 39085 Boston Restaurant Associates,   BRAI   0.96        NaT        0.00
#
# ...

# %%
for i in df107.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
xl08 = pd.ExcelFile('2008.xlsx', low_memory=False)
print(xl08.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df108 = xl08.parse(xl08.sheet_names[0])
df208 = xl08.parse(xl08.sheet_names[1])

# %%
df108.head()
# Out:
#                              Date Name price_date  \
# 0  39478 012 Smile.Communications Ltd. 2008-01-31
# 1           39472 1-800-ATTORNEY, Inc. 2008-01-25
# 2        39478 1-800-FLOWERS.COM, Inc. 2008-01-31
# 3     39469 1608557 Ontario Inc. (USA) 2008-01-22
# 4         39477 1st Centennial Bancorp 2008-01-30
#
#                          company Ticker Standard and Poor stock  \
# 0  012 Smile.Communications Ltd.   SMLC                    None
# 1           1-800-ATTORNEY, Inc.   ATTY                    None
# 2        1-800-FLOWERS.COM, Inc.   FLWS                    None
# 3     1608557 Ontario Inc. (USA)  HMSLQ                    None
# 4         1st Centennial Bancorp   FCEN                    None
#
#              Sector SIC primary code                               Industry  \
# 0     09 - Services             4899         0915 - Communications Services
# 1     09 - Services             2741           0927 - Printing & Publishing
# ...

# %%
df208.head()
# Out:
#                                      price_date  \
# 39449 Auto-Graphics, Inc.            2008-01-02
# 39449 Auto-Graphics, Inc.            2008-01-02
# 39449 Coded Communications           2008-01-02
# 39449 Electronic Tele-Communications 2008-01-02
# 39449 Lancer Orthodontics, Inc.      2008-01-02
#
#                                                              company ticker  \
# 39449 Auto-Graphics, Inc.                        Auto-Graphics, Inc.   AUGR
# 39449 Auto-Graphics, Inc.                        Auto-Graphics, Inc.   AUGR
# 39449 Coded Communications                      Coded Communications  CODDQ
# 39449 Electronic Tele-Communications  Electronic Tele-Communications  ETCIA
# 39449 Lancer Orthodontics, Inc.            Lancer Orthodontics, Inc.   LANZ
#
#                                       price split_date  split_fact  \
# 39449 Auto-Graphics, Inc.              0.77 2000-02-28        3.00
# 39449 Auto-Graphics, Inc.              0.77 2000-02-28        3.00
# ...

# %%
for i in df108.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
xl09 = pd.ExcelFile('2009.xlsx', low_memory=False)
print(xl09.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df109 = xl09.parse(xl09.sheet_names[0])
df209 = xl09.parse(xl09.sheet_names[1])

# %%
df109.head()
# Out:
#                               Date Name price_date  \
# 0  39840 012Smile.Communications Ltd. ( 2009-01-27
# 1            39813 1-800-ATTORNEY, Inc. 2008-12-31
# 2         39843 1-800-FLOWERS.COM, Inc. 2009-01-30
# 3                 39843 141 Capital Inc 2009-01-30
# 4      39841 1608557 Ontario Inc. (USA) 2009-01-28
#
#                           company Ticker Standard and Poor stock  \
# 0  012Smile.Communications Ltd. (   SMLC                    None
# 1            1-800-ATTORNEY, Inc.   ATTY                    None
# 2         1-800-FLOWERS.COM, Inc.   FLWS                    None
# 3                 141 Capital Inc   OFON                    None
# 4      1608557 Ontario Inc. (USA)  HMSLQ                    None
#
#              Sector SIC primary code                               Industry  \
# 0     09 - Services             4899         0915 - Communications Services
# 1     09 - Services             2741           0927 - Printing & Publishing
# ...

# %%
df209.head()
# Out:
#                                      price_date  \
# 39815 AJS Bancorp, Inc.              2009-01-02
# 39815 Amwest Insurance Group         2009-01-02
# 39815 American Consumers,Inc.        2009-01-02
# 39815 American Consumers,Inc.        2009-01-02
# 39815 American Telecom Services, Inc 2009-01-02
#
#                                                              company ticker  \
# 39815 AJS Bancorp, Inc.                            AJS Bancorp, Inc.   AJSB
# 39815 Amwest Insurance Group                  Amwest Insurance Group   AMWT
# 39815 American Consumers,Inc.                American Consumers,Inc.   ANCS
# 39815 American Consumers,Inc.                American Consumers,Inc.   ANCS
# 39815 American Telecom Services, Inc  American Telecom Services, Inc   ATEL
#
#                                       price split_date  split_fact  \
# 39815 AJS Bancorp, Inc.               15.99        NaT         0.0
# 39815 Amwest Insurance Group           0.01 1999-03-29         1.1
# ...

# %%
for i in df109.columns:
    print(i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
xl10 = pd.ExcelFile('2010.xlsx', low_memory=False)
print(xl10.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df101 = xl10.parse(xl10.sheet_names[0])
df102 = xl10.parse(xl10.sheet_names[1])

# %%
df101.head()
# Out:
#                               Date Name price_date  \
# 0  40207 012Smile.Communications Ltd. ( 2010-01-29
# 1            40177 1-800-ATTORNEY, Inc. 2009-12-30
# 2         40207 1-800-FLOWERS.COM, Inc. 2010-01-29
# 3                 40207 141 Capital Inc 2010-01-29
# 4      40206 1608557 Ontario Inc. (USA) 2010-01-28
#
#                           company Ticker Standard and Poor stock  \
# 0  012Smile.Communications Ltd. (   SMLC                    None
# 1            1-800-ATTORNEY, Inc.   ATTY                    None
# 2         1-800-FLOWERS.COM, Inc.   FLWS                    None
# 3                 141 Capital Inc   ONCP                    None
# 4      1608557 Ontario Inc. (USA)  HMSLQ                    None
#
#              Sector SIC primary code                               Industry  \
# 0     09 - Services             4899         0915 - Communications Services
# 1     09 - Services             2741           0927 - Printing & Publishing
# ...

# %%
df102.head()
# Out:
#                                 price_date                    company ticker  \
# 40207 Agilent Technologies Inc. 2010-01-29  Agilent Technologies Inc.      A
# 40235 Agilent Technologies Inc. 2010-02-26  Agilent Technologies Inc.      A
# 40268 Agilent Technologies Inc. 2010-03-31  Agilent Technologies Inc.      A
# 40298 Agilent Technologies Inc. 2010-04-30  Agilent Technologies Inc.      A
# 40326 Agilent Technologies Inc. 2010-05-28  Agilent Technologies Inc.      A
#
#                                  price split_price  split_fact  \
# 40207 Agilent Technologies Inc.  28.03         NaT         0.0
# 40235 Agilent Technologies Inc.  31.46         NaT         0.0
# 40268 Agilent Technologies Inc.  34.39         NaT         0.0
# 40298 Agilent Technologies Inc.  36.26         NaT         0.0
# 40326 Agilent Technologies Inc.  32.36         NaT         0.0
#
#                                  Split_Adjusted Price    P+1    P+2    P+3  \
# ...

# %%
for i in df101.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
xl11 = pd.ExcelFile('2011.xlsx', low_memory=False)
print(xl11.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df111 = xl11.parse(xl11.sheet_names[0])
df112 = xl11.parse(xl11.sheet_names[1])

# %%
df111.head()
# Out:
#                             Date Name price_date  \
# 0          40547 1-800-ATTORNEY, Inc. 2011-01-04
# 1       40574 1-800-FLOWERS.COM, Inc. 2011-01-31
# 2    40574 1608557 Ontario Inc. (USA) 2011-01-31
# 3        40563 1st Centennial Bancorp 2011-01-20
# 4  40571 1st Century Bancshares, Inc. 2011-01-28
#
#                         company Ticker Standard and Poor stock  \
# 0          1-800-ATTORNEY, Inc.   ATTY                    None
# 1       1-800-FLOWERS.COM, Inc.   FLWS                    None
# 2    1608557 Ontario Inc. (USA)  OTROQ                    None
# 3        1st Centennial Bancorp   FCEN                    None
# 4  1st Century Bancshares, Inc.   FCTY                    None
#
#              Sector SIC primary code                               Industry  \
# 0     09 - Services             2741           0927 - Printing & Publishing
# 1     09 - Services             5992  0963 - Retail (Specialty Non-Apparel)
# ...

# %%
df112.head()
# Out:
#                                 price_date                    company ticker  \
# 40574 Agilent Technologies Inc. 2011-01-31  Agilent Technologies Inc.      A
# 40602 Agilent Technologies Inc. 2011-02-28  Agilent Technologies Inc.      A
# 40633 Agilent Technologies Inc. 2011-03-31  Agilent Technologies Inc.      A
# 40662 Agilent Technologies Inc. 2011-04-29  Agilent Technologies Inc.      A
# 40694 Agilent Technologies Inc. 2011-05-31  Agilent Technologies Inc.      A
#
#                                  price split_price  split_fact  \
# 40574 Agilent Technologies Inc.  41.83         NaT         0.0
# 40602 Agilent Technologies Inc.  42.08         NaT         0.0
# 40633 Agilent Technologies Inc.  44.78         NaT         0.0
# 40662 Agilent Technologies Inc.  49.91         NaT         0.0
# 40694 Agilent Technologies Inc.  49.87         NaT         0.0
#
#                                  Split_Adjusted Price    P+1    P+2    P+3  \
# ...

# %%
for i in df111.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
featureFile = pd.ExcelFile('Data for archana.xlsx')     
#features = featureFile.parse(featureFile.sheet_names[0]) 
features = features.loc[features['Unnamed: 2'] == 'x']   
                                                        
features = features['long_name']                       
                                                         
features = features.tolist()
features = [fea.lower() for fea in features]
required_features = ['company'] + features

# %%
print("Before removing nullvalues: ",len(df1))
df1.dropna(inplace = True)
print("After removing null",len(df1))
# Out:
# Before removing nullvalues:  104431
# After removing null 3969

# %%
print("Before removing nullvalues: ",len(df106))
df106.dropna(inplace = True)
print("After removing null",len(df106))
# Out:
# Before removing nullvalues:  104201
# After removing null 4393

# %%
print("Before removing nullvalues: ",len(df107))
df107.dropna(inplace = True)
print("After removing null",len(df107))
# Out:
# Before removing nullvalues:  105579
# After removing null 4975

# %%
print("Before removing nullvalues: ",len(df108))
df108.dropna(inplace = True)
print("After removing null",len(df108))
# Out:
# Before removing nullvalues:  98190
# After removing null 4745

# %%
print("Before removing nullvalues: ",len(df109))
df109.dropna(inplace = True)
print("After removing null",len(df109))
# Out:
# Before removing nullvalues:  116458
# After removing null 4595

# %%
print("Before removing nullvalues: ",len(df101))
df101.dropna(inplace = True)
print("After removing null",len(df101))
# Out:
# Before removing nullvalues:  117859
# After removing null 4152

# %%
print("Before removing nullvalues: ",len(df111))
df111.dropna(inplace = True)
print("After removing null",len(df111))
# Out:
# Before removing nullvalues:  119666
# After removing null 4170

# %%
df1.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df106.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df107.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df108.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df109.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df101.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
df111.isna().any()
# Out:
# Date Name                      False
# price_date                     False
# company                        False
# Ticker                         False
# Standard and Poor stock        False
# Sector                         False
# SIC primary code               False
# Industry                       False
# EPS Est Q0                     False
# EPS Est Q0-% Rev-Last Month    False
# EPS Est Q0-Last month          False
# EPS Est Q0-Number              False
# EPS Est Q0-Revisions down      False
# EPS Est Q0-Revisions up        False
# EPS Est Q1                     False
# EPS Est Q1-% Rev-Last Month    False
# EPS Est Q1-Last month          False
# EPS Est Q1-Number              False
# EPS Est Q1-Revisions down      False
# EPS Est Q1-Revisions up        False
# EPS Est Y0                     False
# EPS Est Y0-% Rev-Last Month    False
# EPS Est Y0-Last month          False
# EPS Est Y0-Number              False
# EPS Est Y0-Revisions down      False
# ...

# %%
featureFile = pd.ExcelFile('Data for archana.xlsx', low_memory = 'false')   
features = featureFile.parse(featureFile.sheet_names[0])

# %%
dff = featureFile.parse(featureFile.sheet_names[0])

# %%
for i in dff:
    print(i)
# Out:
# short_name
# long_name
# unnamed: 2

# %%
for i in df111.columns:
    print (i)
# Out:
# Date Name
# price_date
# company
# Ticker
# Standard and Poor stock
# Sector
# SIC primary code
# Industry
# EPS Est Q0
# EPS Est Q0-% Rev-Last Month
# EPS Est Q0-Last month
# EPS Est Q0-Number
# EPS Est Q0-Revisions down
# EPS Est Q0-Revisions up
# EPS Est Q1
# EPS Est Q1-% Rev-Last Month
# EPS Est Q1-Last month
# EPS Est Q1-Number
# EPS Est Q1-Revisions down
# EPS Est Q1-Revisions up
# EPS Est Y0
# EPS Est Y0-% Rev-Last Month
# EPS Est Y0-Last month
# EPS Est Y0-Number
# EPS Est Y0-Revisions down
# EPS Est Y0-Revisions up
# EPS Est Y1
# EPS Est Y1-% Rev-Last Month
# EPS Est Y1-Last month
# EPS Est Y1-Number
# EPS Est Y1-Revisions down
# EPS Est Y1-Revisions up
# EPS Est Y2
# EPS Est Y2-% Rev-Last Month
# EPS Est Y2-Last month
# EPS Est Y2-Number
# EPS Est Y2-Revisions down
# EPS Est Y2-Revisions up
# EPS Growth Est
# EPS Growth Est-Last month
# EPS Growth Est-Number
# EPS Growth Est-Revisions down
# EPS Growth Est-Revisions up
# EPS Growth-Est Y0 to Est Y1
# ...

# %%
dff = features.loc[features['Unnamed: 2'] == 'x']   
                                                        
dff = dff['long_name']                       
                                                         
dff = dff.tolist()
dff = [fea.lower() for fea in features]
required_features = ['company'] + dff

# %%
for i in required_features:
    print(i.upper())
# Out:
# COMPANY
# EPS EST Q0-% REV-LAST MONTH
# EPS EST Q0-REVISIONS DOWN
# EPS EST Q0-REVISIONS UP
# EPS EST Y0
# EPS EST Y0-% REV-LAST MONTH
# EPS EST Y0-LAST MONTH
# EPS EST Y0-REVISIONS DOWN
# EPS EST Y0-REVISIONS UP
# EPS EST Y1
# EPS EST Y1-% REV-LAST MONTH
# EPS EST Y1-LAST MONTH
# EPS EST Y1-REVISIONS DOWN
# EPS EST Y1-REVISIONS UP
# EPS EST Y2
# EPS EST Y2-% REV-LAST MONTH
# EPS EST Y2-LAST MONTH
# EPS EST Y2-REVISIONS DOWN
# EPS EST Y2-REVISIONS UP
# EPS GROWTH EST
# EPS GROWTH EST-LAST MONTH
# EPS GROWTH EST-REVISIONS DOWN
# EPS GROWTH EST-REVISIONS UP
# EPS GROWTH-EST Y0 TO EST Y1
# EPS GROWTH-EST Y1 TO EST Y2
# QUARTERLY SURPRISE-DIFFERENCE
# QUARTERLY SURPRISE-PERCENT
# QUARTERLY SURPRISE-SUE Q1
# PE
# PE RELATIVE ADJUSTED P/E
# PE TO EPS EST GROWTH 5 YEARS
# PE TO EPS GROWTH 5 YEARS
# PE-AVERAGE 3 YEARS
# PE-FORWARD EPS EST Y0
# PE-FORWARD EPS EST Y1
# PE-FORWARD EPS EST Y2
# PRICE/BOOK
# PRICE/SALES
# NET INSIDER BUYS % SHARES OUT.
# INSTITUTIONAL OWNERSHIP %
# MARKET CAP Q1
# ...

# %%
cl = [
    
"P+1",
"P+2",
"P+3",
"P+4",
"P+5",
"P+6",
"P+7",
"P+8",
"P+9",
"P+10",
"P+11",
"P+12",
"R+1",
"R+2",
"R+3",
"R+4",
"R+5",
"R+6",
"R+7",
"R+8",
"R+9",
"R+10",
"R+11",
"R+12",
]
